# %%
import pandas as pd

# Crear datos de ejemplo
datos = {
    "Nombre": ["Ana", "Luis", "Carlos"],
    "Edad": [23, 25, 22]
}

df = pd.DataFrame(datos)

print(df)
# Out:
#    Nombre  Edad
# 0     Ana    23
# 1    Luis    25
# 2  Carlos    22
